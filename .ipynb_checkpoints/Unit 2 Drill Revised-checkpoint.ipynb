# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.mlab import PCA as mlabPCA
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


import matplotlib.ticker as mtick
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
sns.set_style("whitegrid")

hate = pd.read_csv('/Users/ezzan/Downloads/hate_crimes.csv')
hate = hate[hate.state != 'District of Columbia']

# %%
hate.head(10)
# Out:
#           state  median_household_income  share_unemployed_seasonal  \
# 0       Alabama                    42278                      0.060
# 1        Alaska                    67629                      0.064
# 2       Arizona                    49254                      0.063
# 3      Arkansas                    44922                      0.052
# 4    California                    60487                      0.059
# 5      Colorado                    60940                      0.040
# 6   Connecticut                    70161                      0.052
# 7      Delaware                    57522                      0.049
# 9       Florida                    46140                      0.052
# 10      Georgia                    49555                      0.058
#
#     share_population_in_metro_areas  share_population_with_high_school_degree  \
# 0                              0.64                                     0.821
# 1                              0.63                                     0.914
# 2                              0.90                                     0.842
# 3                              0.69                                     0.824
# 4                              0.97                                     0.806
# 5                              0.80                                     0.893
# 6                              0.94                                     0.886
# 7                              0.90                                     0.874
# 9                              0.96                                     0.853
# 10                             0.82                                     0.839
#
#     share_non_citizen  share_white_poverty  gini_index  share_non_white  \
# 0                0.02                 0.12       0.472             0.35
# 1                0.04                 0.06       0.422             0.42
# 2                0.10                 0.09       0.455             0.49
# 3                0.04                 0.12       0.458             0.26
# 4                0.13                 0.09       0.471             0.61
# 5                0.06                 0.07       0.457             0.31
# 6                0.06                 0.06       0.486             0.30
# 7                0.05                 0.08       0.440             0.37
# 9                0.09                 0.11       0.474             0.46
# 10               0.08                 0.09       0.468             0.48
#
#     share_voters_voted_trump  hate_crimes_per_100k_splc  \
# 0                       0.63                   0.125839
# 1                       0.53                   0.143740
# 2                       0.50                   0.225320
# 3                       0.60                   0.069061
# 4                       0.33                   0.255805
# 5                       0.44                   0.390523
# 6                       0.41                   0.335392
# 7                       0.42                   0.322754
# 9                       0.49                   0.187521
# 10                      0.51                   0.120420
#
#     avg_hatecrimes_per_100k_fbi
# 0                      1.806410
# 1                      1.656700
# 2                      3.413928
# 3                      0.869209
# 4                      2.397986
# 5                      2.804689
# 6                      3.772701
# 7                      1.469980
# 9                      0.698070
# 10                     0.412012

# %%
for col in hate.columns:
    print(hate[col].describe())
# Out:
# count            51
# unique           51
# top       Louisiana
# freq              1
# Name: state, dtype: object
# count       51.000000
# mean     55223.607843
# std       9208.478170
# min      35521.000000
# 25%      48657.000000
# 50%      54916.000000
# 75%      60719.000000
# max      76165.000000
# Name: median_household_income, dtype: float64
# count    51.000000
# mean      0.049569
# std       0.010698
# min       0.028000
# 25%       0.042000
# 50%       0.051000
# 75%       0.057500
# max       0.073000
# Name: share_unemployed_seasonal, dtype: float64
# count    51.000000
# mean      0.750196
# std       0.181587
# min       0.310000
# 25%       0.630000
# 50%       0.790000
# 75%       0.895000
# max       1.000000
# Name: share_population_in_metro_areas, dtype: float64
# count    51.000000
# mean      0.869118
# std       0.034073
# min       0.799000
# 25%       0.840500
# 50%       0.874000
# 75%       0.898000
# max       0.918000
# Name: share_population_with_high_school_degree, dtype: float64
# count    48.000000
# mean      0.054583
# std       0.031077
# min       0.010000
# 25%       0.030000
# 50%       0.045000
# 75%       0.080000
# max       0.130000
# Name: share_non_citizen, dtype: float64
# count    51.000000
# mean      0.091765
# std       0.024715
# min       0.040000
# 25%       0.075000
# 50%       0.090000
# 75%       0.100000
# max       0.170000
# Name: share_white_poverty, dtype: float64
# count    51.000000
# mean      0.453765
# std       0.020891
# min       0.419000
# 25%       0.440000
# 50%       0.454000
# 75%       0.466500
# max       0.532000
# Name: gini_index, dtype: float64
# count    51.000000
# mean      0.315686
# std       0.164915
# min       0.060000
# 25%       0.195000
# 50%       0.280000
# 75%       0.420000
# max       0.810000
# Name: share_non_white, dtype: float64
# count    51.00000
# mean      0.49000
# std       0.11871
# min       0.04000
# 25%       0.41500
# 50%       0.49000
# 75%       0.57500
# max       0.70000
# Name: share_voters_voted_trump, dtype: float64
# count    47.000000
# mean      0.304093
# std       0.252709
# min       0.067447
# 25%       0.142707
# 50%       0.226197
# 75%       0.356935
# max       1.522302
# Name: hate_crimes_per_100k_splc, dtype: float64
# count    50.000000
# mean      2.367613
# std       1.714245
# min       0.266941
# 25%       1.293139
# 50%       1.987068
# 75%       3.184344
# max      10.953480
# Name: avg_hatecrimes_per_100k_fbi, dtype: float64

# %%
df_jittered = hate.loc[:, 'median_household_income':'avg_hatecrimes_per_100k_fbi']

jitter = pd.DataFrame(
    np.random.uniform(0, 1, size=(df_jittered.shape)),
    columns=df_jittered.columns
)

df_jittered = df_jittered.add(jitter)

# %%
# Declare that you want to make a scatterplot matrix.
g = sns.PairGrid(df_jittered.dropna(), diag_sharey=False)
# Scatterplot.
g.map_upper(plt.scatter, alpha=.5)
# Fit line summarizing the linear relationship of the two variables.
g.map_lower(sns.regplot, scatter_kws=dict(alpha=0))
# Give information about the univariate distributions of the variables.
g.map_diag(sns.kdeplot, lw=3)
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
corrmat = hate.corr()
print(corrmat)
f, ax = plt.subplots(figsize=(12, 9))

sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
# Out:
#                                           median_household_income  \
# median_household_income                                  1.000000
# share_unemployed_seasonal                               -0.376722
# share_population_in_metro_areas                          0.286480
# share_population_with_high_school_degree                 0.653490
# share_non_citizen                                        0.302288
# share_white_poverty                                     -0.818045
# gini_index                                              -0.178821
# share_non_white                                          0.103775
# share_voters_voted_trump                                -0.597528
# hate_crimes_per_100k_splc                                0.350714
# avg_hatecrimes_per_100k_fbi                              0.318246
#
#                                           share_unemployed_seasonal  \
# median_household_income                                   -0.376722
# share_unemployed_seasonal                                  1.000000
# share_population_in_metro_areas                            0.358113
# share_population_with_high_school_degree                  -0.621168
# share_non_citizen                                          0.278899
# share_white_poverty                                        0.209440
# gini_index                                                 0.541659
# share_non_white                                            0.431847
# share_voters_voted_trump                                  -0.148192
# hate_crimes_per_100k_splc                                  0.083292
# avg_hatecrimes_per_100k_fbi                                0.073936
#
#                                           share_population_in_metro_areas  \
# median_household_income                                          0.286480
# share_unemployed_seasonal                                        0.358113
# share_population_in_metro_areas                                  1.000000
# share_population_with_high_school_degree                        -0.268846
# share_non_citizen                                                0.745464
# share_white_poverty                                             -0.385559
# gini_index                                                       0.515843
# share_non_white                                                  0.547672
# share_voters_voted_trump                                        -0.570695
# hate_crimes_per_100k_splc                                        0.162217
# avg_hatecrimes_per_100k_fbi                                      0.209827
#
#                                           share_population_with_high_school_degree  \
# median_household_income                                                   0.653490
# share_unemployed_seasonal                                                -0.621168
# share_population_in_metro_areas                                          -0.268846
# share_population_with_high_school_degree                                  1.000000
# share_non_citizen                                                        -0.277009
# share_white_poverty                                                      -0.494008
# gini_index                                                               -0.592052
# share_non_white                                                          -0.434846
# share_voters_voted_trump                                                 -0.155656
# hate_crimes_per_100k_splc                                                 0.308944
# avg_hatecrimes_per_100k_fbi                                               0.164148
#
#                                           share_non_citizen  \
# median_household_income                            0.302288
# share_unemployed_seasonal                          0.278899
# share_population_in_metro_areas                    0.745464
# share_population_with_high_school_degree          -0.277009
# share_non_citizen                                  1.000000
# share_white_poverty                               -0.389718
# gini_index                                         0.480257
# share_non_white                                    0.733655
# share_voters_voted_trump                          -0.631194
# hate_crimes_per_100k_splc                          0.243507
# avg_hatecrimes_per_100k_fbi                        0.300892
#
#                                           share_white_poverty  gini_index  \
# median_household_income                             -0.818045   -0.178821
# share_unemployed_seasonal                            0.209440    0.541659
# share_population_in_metro_areas                     -0.385559    0.515843
# share_population_with_high_school_degree            -0.494008   -0.592052
# share_non_citizen                                   -0.389718    0.480257
# share_white_poverty                                  1.000000    0.032584
# gini_index                                           0.032584    1.000000
# share_non_white                                     -0.269449    0.468467
# share_voters_voted_trump                             0.552849   -0.411543
# hate_crimes_per_100k_splc                           -0.286170    0.329439
# avg_hatecrimes_per_100k_fbi                         -0.260094    0.421272
#
#                                           share_non_white  \
# median_household_income                          0.103775
# share_unemployed_seasonal                        0.431847
# share_population_in_metro_areas                  0.547672
# share_population_with_high_school_degree        -0.434846
# share_non_citizen                                0.733655
# share_white_poverty                             -0.269449
# gini_index                                       0.468467
# share_non_white                                  1.000000
# share_voters_voted_trump                        -0.488838
# hate_crimes_per_100k_splc                        0.047561
# avg_hatecrimes_per_100k_fbi                      0.083525
#
#                                           share_voters_voted_trump  \
# median_household_income                                  -0.597528
# share_unemployed_seasonal                                -0.148192
# share_population_in_metro_areas                          -0.570695
# share_population_with_high_school_degree                 -0.155656
# share_non_citizen                                        -0.631194
# share_white_poverty                                       0.552849
# gini_index                                               -0.411543
# share_non_white                                          -0.488838
# share_voters_voted_trump                                  1.000000
# hate_crimes_per_100k_splc                                -0.657067
# avg_hatecrimes_per_100k_fbi                              -0.504532
#
#                                           hate_crimes_per_100k_splc  \
# median_household_income                                    0.350714
# share_unemployed_seasonal                                  0.083292
# share_population_in_metro_areas                            0.162217
# share_population_with_high_school_degree                   0.308944
# share_non_citizen                                          0.243507
# share_white_poverty                                       -0.286170
# gini_index                                                 0.329439
# share_non_white                                            0.047561
# share_voters_voted_trump                                  -0.657067
# hate_crimes_per_100k_splc                                  1.000000
# avg_hatecrimes_per_100k_fbi                                0.758700
#
#                                           avg_hatecrimes_per_100k_fbi
# median_household_income                                      0.318246
# share_unemployed_seasonal                                    0.073936
# share_population_in_metro_areas                              0.209827
# share_population_with_high_school_degree                     0.164148
# share_non_citizen                                            0.300892
# share_white_poverty                                         -0.260094
# gini_index                                                   0.421272
# share_non_white                                              0.083525
# share_voters_voted_trump                                    -0.504532
# hate_crimes_per_100k_splc                                    0.758700
# avg_hatecrimes_per_100k_fbi                                  1.000000

# %%
# Plot all the variables with boxplots for each country.

# Restructure the data so we can use FacetGrid rather than making a boxplot
# for each variable separately.
df_long = hate
df_long = pd.melt(df_long, id_vars=['state'])

g = sns.FacetGrid(df_long, col="variable", size=4, aspect=.5)
g = g.map(sns.boxplot, "state", "value")

plt.show()

# Descriptive statistics by group.
print(hate.groupby('state').describe())

# Test whether group differences are significant.
for col in hate.loc[:,'share_unemployed_seasonal': 'share_voters_voted_trump'].columns:
    print(col)
    print(stats.ttest_ind(
        hate[hate['state'] == 'New York'][col].dropna(),
        hate[hate['state'] == 'California'][col].dropna()
    ))
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\seaborn\axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
#                      avg_hatecrimes_per_100k_fbi                            \
#                                            count       mean std        min
# state
# Alabama                                      1.0   1.806410 NaN   1.806410
# Alaska                                       1.0   1.656700 NaN   1.656700
# Arizona                                      1.0   3.413928 NaN   3.413928
# Arkansas                                     1.0   0.869209 NaN   0.869209
# California                                   1.0   2.397986 NaN   2.397986
# Colorado                                     1.0   2.804689 NaN   2.804689
# Connecticut                                  1.0   3.772701 NaN   3.772701
# Delaware                                     1.0   1.469980 NaN   1.469980
# District of Columbia                         1.0  10.953480 NaN  10.953480
# Florida                                      1.0   0.698070 NaN   0.698070
# Georgia                                      1.0   0.412012 NaN   0.412012
# Hawaii                                       0.0        NaN NaN        NaN
# Idaho                                        1.0   1.891331 NaN   1.891331
# Illinois                                     1.0   1.044016 NaN   1.044016
# Indiana                                      1.0   1.757357 NaN   1.757357
# Iowa                                         1.0   0.561396 NaN   0.561396
# Kansas                                       1.0   2.143987 NaN   2.143987
# Kentucky                                     1.0   4.207890 NaN   4.207890
# Louisiana                                    1.0   1.341170 NaN   1.341170
# Maine                                        1.0   2.626611 NaN   2.626611
# Maryland                                     1.0   1.324840 NaN   1.324840
# Massachusetts                                1.0   4.801899 NaN   4.801899
# Michigan                                     1.0   3.200442 NaN   3.200442
# Minnesota                                    1.0   3.612412 NaN   3.612412
# Mississippi                                  1.0   0.622746 NaN   0.622746
# Missouri                                     1.0   1.908955 NaN   1.908955
# Montana                                      1.0   2.954959 NaN   2.954959
# Nebraska                                     1.0   2.686248 NaN   2.686248
# Nevada                                       1.0   2.113990 NaN   2.113990
# New Hampshire                                1.0   2.105989 NaN   2.105989
# New Jersey                                   1.0   4.413203 NaN   4.413203
# New Mexico                                   1.0   1.886435 NaN   1.886435
# New York                                     1.0   3.102164 NaN   3.102164
# North Carolina                               1.0   1.262680 NaN   1.262680
# Utah                  0.419  ...                      0.47  0.47
# Vermont               0.444  ...                      0.33  0.33
# Virginia              0.459  ...                      0.45  0.45
# Washington            0.441  ...                      0.38  0.38
# West Virginia         0.451  ...                      0.69  0.69
# Wisconsin             0.430  ...                      0.48  0.48
# Wyoming               0.423  ...                      0.70  0.70
#
#                      share_white_poverty                                    \
#                                    count  mean std   min   25%   50%   75%
# state
# Alabama                              1.0  0.12 NaN  0.12  0.12  0.12  0.12
# Alaska                               1.0  0.06 NaN  0.06  0.06  0.06  0.06
# Arizona                              1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Arkansas                             1.0  0.12 NaN  0.12  0.12  0.12  0.12
# California                           1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Colorado                             1.0  0.07 NaN  0.07  0.07  0.07  0.07
# Connecticut                          1.0  0.06 NaN  0.06  0.06  0.06  0.06
# Delaware                             1.0  0.08 NaN  0.08  0.08  0.08  0.08
# District of Columbia                 1.0  0.04 NaN  0.04  0.04  0.04  0.04
# Florida                              1.0  0.11 NaN  0.11  0.11  0.11  0.11
# Georgia                              1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Hawaii                               1.0  0.07 NaN  0.07  0.07  0.07  0.07
# Idaho                                1.0  0.11 NaN  0.11  0.11  0.11  0.11
# Illinois                             1.0  0.07 NaN  0.07  0.07  0.07  0.07
# Indiana                              1.0  0.12 NaN  0.12  0.12  0.12  0.12
# Iowa                                 1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Kansas                               1.0  0.11 NaN  0.11  0.11  0.11  0.11
# Kentucky                             1.0  0.17 NaN  0.17  0.17  0.17  0.17
# Louisiana                            1.0  0.12 NaN  0.12  0.12  0.12  0.12
# Maine                                1.0  0.12 NaN  0.12  0.12  0.12  0.12
# Maryland                             1.0  0.06 NaN  0.06  0.06  0.06  0.06
# Massachusetts                        1.0  0.08 NaN  0.08  0.08  0.08  0.08
# Michigan                             1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Minnesota                            1.0  0.05 NaN  0.05  0.05  0.05  0.05
# Mississippi                          1.0  0.14 NaN  0.14  0.14  0.14  0.14
# Missouri                             1.0  0.07 NaN  0.07  0.07  0.07  0.07
# Montana                              1.0  0.10 NaN  0.10  0.10  0.10  0.10
# Nebraska                             1.0  0.07 NaN  0.07  0.07  0.07  0.07
# Nevada                               1.0  0.08 NaN  0.08  0.08  0.08  0.08
# New Hampshire                        1.0  0.06 NaN  0.06  0.06  0.06  0.06
# New Jersey                           1.0  0.07 NaN  0.07  0.07  0.07  0.07
# New Mexico                           1.0  0.10 NaN  0.10  0.10  0.10  0.10
# New York                             1.0  0.10 NaN  0.10  0.10  0.10  0.10
# North Carolina                       1.0  0.10 NaN  0.10  0.10  0.10  0.10
# North Dakota                         1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Ohio                                 1.0  0.10 NaN  0.10  0.10  0.10  0.10
# Oklahoma                             1.0  0.10 NaN  0.10  0.10  0.10  0.10
# Oregon                               1.0  0.10 NaN  0.10  0.10  0.10  0.10
# Pennsylvania                         1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Rhode Island                         1.0  0.08 NaN  0.08  0.08  0.08  0.08
# South Carolina                       1.0  0.09 NaN  0.09  0.09  0.09  0.09
# South Dakota                         1.0  0.08 NaN  0.08  0.08  0.08  0.08
# Tennessee                            1.0  0.13 NaN  0.13  0.13  0.13  0.13
# Texas                                1.0  0.08 NaN  0.08  0.08  0.08  0.08
# Utah                                 1.0  0.08 NaN  0.08  0.08  0.08  0.08
# Vermont                              1.0  0.10 NaN  0.10  0.10  0.10  0.10
# Virginia                             1.0  0.07 NaN  0.07  0.07  0.07  0.07
# Washington                           1.0  0.09 NaN  0.09  0.09  0.09  0.09
# West Virginia                        1.0  0.14 NaN  0.14  0.14  0.14  0.14
# Wisconsin                            1.0  0.09 NaN  0.09  0.09  0.09  0.09
# Wyoming                              1.0  0.09 NaN  0.09  0.09  0.09  0.09
#
#
#                        max
# state
# Alabama               0.12
# Alaska                0.06
# Arizona               0.09
# Arkansas              0.12
# California            0.09
# Colorado              0.07
# Connecticut           0.06
# Delaware              0.08
# District of Columbia  0.04
# Florida               0.11
# Georgia               0.09
# Hawaii                0.07
# Idaho                 0.11
# Illinois              0.07
# Indiana               0.12
# Iowa                  0.09
# Kansas                0.11
# Kentucky              0.17
# Louisiana             0.12
# Maine                 0.12
# Maryland              0.06
# Massachusetts         0.08
# Michigan              0.09
# Minnesota             0.05
# Mississippi           0.14
# Missouri              0.07
# Montana               0.10
# Nebraska              0.07
# Nevada                0.08
# New Hampshire         0.06
# New Jersey            0.07
# New Mexico            0.10
# New York              0.10
# North Carolina        0.10
# North Dakota          0.09
# Ohio                  0.10
# Oklahoma              0.10
# Oregon                0.10
# Pennsylvania          0.09
# Rhode Island          0.08
# South Carolina        0.09
# South Dakota          0.08
# Tennessee             0.13
# Texas                 0.08
# Utah                  0.08
# Vermont               0.10
# Virginia              0.07
# Washington            0.09
# West Virginia         0.14
# Wisconsin             0.09
# Wyoming               0.09
#
# [51 rows x 88 columns]
# share_unemployed_seasonal
# Ttest_indResult(statistic=nan, pvalue=nan)
# share_population_in_metro_areas
# Ttest_indResult(statistic=nan, pvalue=nan)
# share_population_with_high_school_degree
# Ttest_indResult(statistic=nan, pvalue=nan)
# share_non_citizen
# Ttest_indResult(statistic=nan, pvalue=nan)
# share_white_poverty
# Ttest_indResult(statistic=nan, pvalue=nan)
# gini_index
# Ttest_indResult(statistic=nan, pvalue=nan)
# share_non_white
# Ttest_indResult(statistic=nan, pvalue=nan)
# share_voters_voted_trump
# Ttest_indResult(statistic=nan, pvalue=nan)
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\numpy\core\fromnumeric.py:3194: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
income = [hate['median_household_income']]
crime_rate = [hate['hate_crimes_per_100k_splc']]

# %%
g = sns.lmplot(y='median_household_income', # Variable 1.
               x='avg_hatecrimes_per_100k_fbi', # Variable 2.
               data=hate, # Data
               fit_reg=True, # If set to true, plots a regression line.
               scatter_kws={'alpha':0.4}) # Set points to semi-transparent to see overlaping points.
g.set_ylabels("Median Income in USD")
g.set_xlabels("Hate Crimes per 100k")
plt.title('Income per Crime Rate')

plt.show()
#seems not the most effecient indicator considering  not clear correltion and outliers


g = sns.lmplot(y='median_household_income', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Median Income in USD")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
g = sns.lmplot(y='share_population_with_high_school_degree', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("Pop. with HS Degree")
g.set_xlabels("Hate Crimes per 100k (SPLC) ")
plt.title('Income per Crime Rate')
plt.show()

# %%
g = sns.lmplot(y='gini_index', # Variable 1.
               x='avg_hatecrimes_per_100k_fbi',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("GINI Index")
g.set_xlabels("Hate Crimes per 100k (FBI)  ")
plt.title('Income per Crime Rate')
plt.show()


g = sns.lmplot(y='gini_index', # Variable 1.
               x='hate_crimes_per_100k_splc',
               data=hate, # Data.
               fit_reg=True, # The regression line also includes a 95% confidence envelope.
               scatter_kws={'alpha':0.4})
g.set_ylabels("GINI Index")
g.set_xlabels("Hate Crimes per 100k (FBI)  ")
plt.title('Income per Crime Rate')
plt.show()

# %%
#it apears from above data that the most postively correlated data sets are
# share pop with hs degree and share employed seasonal
# share non white and share population in metro areas
# share pop with hs degree and gini index
hate1 = hate[["state", "median_household_income", "share_unemployed_seasonal", "avg_hatecrimes_per_100k_fbi","gini_index","share_population_with_high_school_degree", "share_non_white"]]

# %%
state_crime1 = hate.sort_values('avg_hatecrimes_per_100k_fbi',ascending=False)
sns.set(style="darkgrid")
g = sns.factorplot(x="avg_hatecrimes_per_100k_fbi", y="state", hue=None, data=state_crime1,
                   size=10, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("state")
g.set_xlabels("crime rate")
plt.title('Crime Rate by State (FBI) ')
plt.show()
sns.set(style="darkgrid")

state_crime2 = hate.sort_values('hate_crimes_per_100k_splc',ascending=False)
g = sns.factorplot(x="hate_crimes_per_100k_splc", y="state", hue=None, data=state_crime2,
                   size=10, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("state")
g.set_xlabels("crime rate")
plt.title('Crime Rate by State (SPLC) ')
plt.show()
