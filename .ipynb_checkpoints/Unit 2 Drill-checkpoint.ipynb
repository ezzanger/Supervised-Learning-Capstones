# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.mlab import PCA as mlabPCA
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


import matplotlib.ticker as mtick
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
sns.set_style("whitegrid")

play = pd.read_csv('/Users/ezzan/Downloads/allstar_player_talent.csv')
team = pd.read_csv('/Users/ezzan/Downloads/allstar_team_talent.csv')

# %%
play.head()
# Out:
#     bbref_ID  yearID  gameNum        gameID lgID  startingPos     OFF600  \
# 0  goldspa01    2015        0  NLS201507140   NL          3.0  36.755724
# 1  mccutan01    2015        0  NLS201507140   NL          8.0  33.676168
# 2  harpebr03    2015        0  NLS201507140   NL          9.0  30.925454
# 3  greinza01    2015        0  NLS201507140   NL          1.0   0.000000
# 4  poseybu01    2015        0  NLS201507140   NL          2.0  21.692969
#
#      DEF600   PITCH200  asg_PA  asg_IP  OFFper9innASG  DEFper9innASG  \
# 0 -0.117214   0.000000       3     0.0       0.183779      -0.000586
# 1 -0.168658   0.000000       3     0.0       0.168381      -0.000843
# 2  1.382969   0.000000       3     0.0       0.154627       0.006915
# 3  0.000000  15.645611       0     2.0       0.000000       0.000000
# 4  7.595546   0.000000       2     0.0       0.072310       0.025318
#
#    PITper9innASG  TOTper9innASG
# 0       0.000000       0.183193
# 1       0.000000       0.167538
# ...

# %%
print(len(play))
# Out:
# 3930

# %%
print(len(team))
# Out:
# 172

# %%
team.head(110)
# Out:
#      yearID  gameNum        gameID lgID  tm_OFF_talent  tm_DEF_talent  \
# 0      1966        0  NLS196607120   NL       1.332265       0.130991
# 1      1986        0  NLS198607150   AL       1.049056       0.356240
# 2      1934        0  NLS193407100   AL       1.778661       0.116654
# 3      1941        0  ALS194107080   AL       1.472107       0.090803
# 4      1940        0  NLS194007090   AL       1.356557       0.138973
# 5      1964        0  NLS196407070   AL       1.178169       0.132762
# 6      1946        0  ALS194607090   AL       0.962761       0.183704
# 7      1972        0  NLS197207250   AL       1.003092       0.126050
# 8      1997        0  ALS199707080   AL       1.254004       0.109234
# 9      1997        0  ALS199707080   NL       1.407035       0.050812
# 10     1965        0  ALS196507130   NL       1.195851       0.003355
# 11     1942        0  NLS194207060   AL       1.120247       0.230409
# ...

# %%
for col in play.columns:
    print(play[col].describe())
# Out:
# count          3930
# unique         1482
# top       musiast01
# freq             24
# Name: bbref_ID, dtype: object
# count    3930.000000
# mean     1977.759542
# std        23.191567
# min      1933.000000
# 25%      1960.000000
# 50%      1979.000000
# 75%      1998.000000
# max      2015.000000
# Name: yearID, dtype: float64
# count    3930.000000
# mean        0.126972
# std         0.441440
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: gameNum, dtype: float64
# count             3930
# unique              86
# top       ALS200807150
# freq                63
# Name: gameID, dtype: object
# count     3930
# unique       2
# top         NL
# freq      1999
# Name: lgID, dtype: object
# count    1579.000000
# mean        5.037365
# std         2.654216
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max        10.000000
# Name: startingPos, dtype: float64
# ...

# %%
for col in team.columns:
    print(team[col].describe())
# Out:
# count     172.000000
# mean     1973.709302
# std        23.577106
# min      1933.000000
# 25%      1955.000000
# 50%      1972.500000
# 75%      1994.000000
# max      2015.000000
# Name: yearID, dtype: float64
# count    172.000000
# mean       0.139535
# std        0.462963
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000
# Name: gameNum, dtype: float64
# count              172
# unique              86
# top       NLS197207250
# freq                 2
# Name: gameID, dtype: object
# count     172
# unique      2
# top        NL
# freq       86
# Name: lgID, dtype: object
# count    172.000000
# mean       0.980740
# std        0.229886
# min        0.329207
# 25%        0.837329
# 50%        0.961385
# 75%        1.112122
# max        1.778661
# Name: tm_OFF_talent, dtype: float64
# count    172.000000
# mean       0.089316
# std        0.085853
# min       -0.126729
# 25%        0.033869
# 50%        0.096315
# ...

# %%
df_jittered = team.loc[:, 'MLB_avg_RPG':'tm_OFF_talent']

jitter = pd.DataFrame(
    np.random.uniform(0, 1, size=(df_jittered.shape)),
    columns=df_jittered.columns
)

df_jittered = df_jittered.add(jitter)

# %%
# Declare that you want to make a scatterplot matrix.
g = sns.PairGrid(df_jittered.dropna(), diag_sharey=False)
# Scatterplot.
g.map_upper(plt.scatter, alpha=.5)
# Fit line summarizing the linear relationship of the two variables.
g.map_lower(sns.regplot, scatter_kws=dict(alpha=0))
# Give information about the univariate distributions of the variables.
g.map_diag(sns.kdeplot, lw=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-6868a23df8d1> in <module>()
#       2
#       3 # Declare that you want to make a scatterplot matrix.
# ----> 4 g = sns.PairGrid(df_jittered.dropna(), diag_sharey=False)
#       5 # Scatterplot.
#       6 g.map_upper(plt.scatter, alpha=.5)
#
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, size, aspect, despine, dropna)
#    1243
#    1244         # Label the axes
# -> 1245         self._add_axis_labels()
#    1246
#    1247         # Sort out the hue variable
#
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\seaborn\axisgrid.py in _add_axis_labels(self)
#    1497     def _add_axis_labels(self):
# ...
